# %% [markdown]
# # 智能问答方案概述
# ### 1. 使用 gensim 训练词向量 iter=10,min_count=4,size=100,workers=6,negative=8,window=5
# ### 2. 基于paddle 构建二分类模型，确定 para 筛选特征
# ### 3. 修改 baseline ，加载（1）训练得词向量 + （2）para筛选方式,1 epoch 40+, 3 epoch 41.805000

# %%
#确定cuda 和 cudnn 版本
# !cat /usr/local/cuda/version.txt
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# CUDA Version 8.0.61
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 1
# #define CUDNN_PATCHLEVEL 3
# --
# #define CUDNN_VERSION    (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
import gensim, logging,json,os
from collections import Counter

# %% [markdown]
# ## 1. 使用 gensim 训练词向量

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
 
root = '/mnt/datasets/dureader/preprocessed/'
s_train = root+'trainset/search.train.json'
z_train = root+'trainset/zhidao.train.json'
s_dev = root +'devset/search.dev.json'
z_dev = root+'devset/zhidao.dev.json'
s_test = root +'testset/search.test.json'
z_test = root +'testset/zhidao.test.json'

fs = [s_train,z_train,s_dev,z_dev,s_test,z_test]

class MySentences(object):
    def __init__(self, dirnames):
        self.dirnames = dirnames
    def __iter__(self):
        for fname in self.dirnames:
            for line in open(fname):
            	obj = json.loads(line.strip())
            	ques_sent = obj['segmented_question']
            	yield ques_sent
            	for doc in obj['documents']:
            		title_sent = doc['segmented_title']
            		yield title_sent
            		for p in doc['segmented_paragraphs']:
            			yield p
sents = MySentences(fs) # a memory-friendly iterator

# %%
# %%time
model = gensim.models.Word2Vec(iter=10,min_count=4,size=100,workers=6,negative=8,window=5)  # an empty model, no training yet
model.build_vocab(sents)  # can be a non-repeatable, 1-pass generator
sents = MySentences(fs)
model.train(sents,total_examples=model.corpus_count,epochs=model.epochs)  # can be a non-repeatable, 1-pass generator
# Out:
# 2018-06-24 07:06:31,498 : INFO : collecting all words and their counts
# 2018-06-24 07:06:31,500 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-06-24 07:06:31,729 : INFO : PROGRESS: at sentence #10000, processed 417539 words, keeping 34082 word types
# 2018-06-24 07:06:31,973 : INFO : PROGRESS: at sentence #20000, processed 834472 words, keeping 49902 word types
# 2018-06-24 07:06:32,219 : INFO : PROGRESS: at sentence #30000, processed 1253373 words, keeping 63265 word types
# 2018-06-24 07:06:32,457 : INFO : PROGRESS: at sentence #40000, processed 1664600 words, keeping 73866 word types
# 2018-06-24 07:06:32,700 : INFO : PROGRESS: at sentence #50000, processed 2087604 words, keeping 82949 word types
# 2018-06-24 07:06:32,953 : INFO : PROGRESS: at sentence #60000, processed 2506449 words, keeping 91513 word types
# 2018-06-24 07:06:33,195 : INFO : PROGRESS: at sentence #70000, processed 2904472 words, keeping 99080 word types
# 2018-06-24 07:06:33,437 : INFO : PROGRESS: at sentence #80000, processed 3310766 words, keeping 106288 word types
# 2018-06-24 07:06:33,680 : INFO : PROGRESS: at sentence #90000, processed 3734237 words, keeping 112983 word types
# 2018-06-24 07:06:33,923 : INFO : PROGRESS: at sentence #100000, processed 4143688 words, keeping 119604 word types
# 2018-06-24 07:06:34,179 : INFO : PROGRESS: at sentence #110000, processed 4565221 words, keeping 125888 word types
words/s, in_qsize 10, out_qsize 1
# 2018-06-24 08:52:30,341 : INFO : EPOCH 10 - PROGRESS: at 98.42% examples, 665268 words/s, in_qsize 11, out_qsize 0
# 2018-06-24 08:52:31,345 : INFO : EPOCH 10 - PROGRESS: at 98.51% examples, 665341 words/s, in_qsize 10, out_qsize 1
# 2018-06-24 08:52:32,355 : INFO : EPOCH 10 - PROGRESS: at 98.61% examples, 665387 words/s, in_qsize 10, out_qsize 1
# 2018-06-24 08:52:33,365 : INFO : EPOCH 10 - PROGRESS: at 98.70% examples, 665376 words/s, in_qsize 11, out_qsize 1
# 2018-06-24 08:52:34,372 : INFO : EPOCH 10 - PROGRESS: at 98.79% examples, 665405 words/s, in_qsize 11, out_qsize 0
# 2018-06-24 08:52:35,388 : INFO : EPOCH 10 - PROGRESS: at 98.89% examples, 665406 words/s, in_qsize 11, out_qsize 0
# 2018-06-24 08:52:36,396 : INFO : EPOCH 10 - PROGRESS: at 98.98% examples, 665438 words/s, in_qsize 11, out_qsize 0
# 2018-06-24 08:52:37,409 : INFO : EPOCH 10 - PROGRESS: at 99.07% examples, 665462 words/s, in_qsize 11, out_qsize 0
# 2018-06-24 08:52:38,424 : INFO : EPOCH 10 - PROGRESS: at 99.17% examples, 665512 words/s, in_qsize 11, out_qsize 0
# 2018-06-24 08:52:39,431 : INFO : EPOCH 10 - PROGRESS: at 99.28% examples, 665546 words/s, in_qsize 11, out_qsize 0
# 2018-06-24 08:52:40,432 : INFO : EPOCH 10 - PROGRESS: at 99.37% examples, 665513 words/s, in_qsize 11, out_qsize 0
# 2018-06-24 08:52:41,433 : INFO : EPOCH 10 - PROGRESS: at 99.48% examples, 665617 words/s, in_qsize 11, out_qsize 0
# 2018-06-24 08:52:42,442 : INFO : EPOCH 10 - PROGRESS: at 99.59% examples, 665697 words/s, in_qsize 12, out_qsize 0
# 2018-06-24 08:52:43,453 : INFO : EPOCH 10 - PROGRESS: at 99.69% examples, 665794 words/s, in_qsize 9, out_qsize 2
# 2018-06-24 08:52:44,462 : INFO : EPOCH 10 - PROGRESS: at 99.79% examples, 665924 words/s, in_qsize 10, out_qsize 1
# 2018-06-24 08:52:45,465 : INFO : EPOCH 10 - PROGRESS: at 99.88% examples, 665970 words/s, in_qsize 10, out_qsize 1
# 2018-06-24 08:52:46,470 : INFO : EPOCH 10 - PROGRESS: at 99.98% examples, 666042 words/s, in_qsize 10, out_qsize 1
# 2018-06-24 08:52:46,607 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-06-24 08:52:46,625 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-06-24 08:52:46,627 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-06-24 08:52:46,628 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-06-24 08:52:46,630 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-06-24 08:52:46,635 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-06-24 08:52:46,638 : INFO : EPOCH - 10 : training on 477969016 raw words (399677134 effective words) took 600.0s, 666159 effective words/s
# 2018-06-24 08:52:46,639 : INFO : training on a 4779690160 raw words (3996802353 effective words) took 6070.8s, 658360 effective words/s
# CPU times: user 5h 5min 32s, sys: 3min 18s, total: 5h 8min 50s
# Wall time: 1h 46min 15s

# %%
## 持久化词向量之前，删除上一次训练生成的 models 和 vocab, 保证不超过工作区空间限制
# !rm -vrf ./data/models/
# !rm -vrf ./data/vocab/

# %%
# %%time
import gzip
# gzip.open(filename, mode='rb', compresslevel=9, encoding=None, errors=None, newline=None)
# https://docs.python.org/3/library/gzip.html
with gzip.open('./100_ver_not_pure.bin', 'wt',compresslevel=9,encoding='utf-8') as f:
    for k in model.wv.vocab.keys():
        s = k+' '+' '.join([str(i) for i in model.wv[k]])
        f.write(s+'\n')
# Out:
# CPU times: user 4min 29s, sys: 492 ms, total: 4min 30s
# Wall time: 4min 30s

# %% [markdown]
# ## 2.基于paddle 构建二分类模型，确定 para 筛选特征
# recall_eq 查询和材料的 word 共现率
# recall_eq_char 查询和材料的 char 共现率
# recall_tq 材料标题和查询的 word 共现率
# recall_tq_char 材料标题和查询的 char 共现率
# 通过组合其中一个或几个特征，通过模型训练效果筛选出适合 para 筛选的特征；
# 最终确定组合 recall_eq 和 recall_eq_char 作为筛选 para 的特征。
#
# **注：kernel 默认环境为 python3 通过将代码写到文件，然后命令行调用 python2 训练 paddlepaddle 模型**

# %%
bst_para_str ='''
"""
This module prepares and runs the whole system.
"""
import sys
if sys.version[0] == '2':
    reload(sys)
    sys.setdefaultencoding("utf-8")
import os
import json
from sklearn.model_selection import train_test_split
import paddle.v2 as paddle  
from paddle.v2.plot import Ploter
import numpy as np  
import random
from collections import Counter

root = '/mnt/datasets/dureader/preprocessed/'
s_train = root+'trainset/search.train.json'
z_train = root+'trainset/zhidao.train.json'
s_dev = root +'devset/search.dev.json'
z_dev = root+'devset/zhidao.dev.json'
s_test = root +'testset/search.test.json'
z_test = root +'testset/zhidao.test.json'

max_p_len = 500
def load_dataset(data_path, train=False):
    """
    Loads the dataset
    Args:
        data_path: the data file to load
    """
    all_paras = []
    with open(data_path) as fin:
        data_set = []
        for lidx, line in enumerate(fin):
            sample = json.loads(line.strip())
            if train:
                if len(sample['answer_spans']) == 0:
                    continue
                if sample['answer_spans'][0][1] >= 500:
                    continue

            if 'answer_docs' in sample:
                sample['answer_passages'] = sample['answer_docs']

            sample['question_tokens'] = sample['segmented_question']

            sample['passages'] = []
            for d_idx, doc in enumerate(sample['documents']):
                if train:
                    most_related_para = doc['most_related_para']
                    sample['passages'].append(
                        {'passage_tokens': doc['segmented_paragraphs'][most_related_para],
                         'is_selected': doc['is_selected']}
                    )
                else:
                    para_infos = []
                    for para_tokens, p_tokens, title,title_tokens in zip(doc['segmented_paragraphs'], doc['paragraphs'], doc['title'], doc['segmented_title']):
                        question_tokens = sample['segmented_question']

                        p_char_tokens = [i for i in p_tokens]
                        title_char_tokens = [i for i in title]
                        q_char_tokens = [i for i in sample['question']]

                        common_with_question = Counter(para_tokens) & Counter(question_tokens)
                        common_with_question_char = Counter(p_char_tokens) & Counter(q_char_tokens)
                        title_common_with_question = Counter(title_tokens) & Counter(question_tokens)
                        title_common_with_question_char = Counter(title_char_tokens) & Counter(q_char_tokens)

                        correct_preds = sum(common_with_question.values())
                        recall_eq = 0 if correct_preds==0 else float(correct_preds) / len(question_tokens)

                        correct_preds = sum(common_with_question_char.values())
                        recall_eq_char = 0 if correct_preds==0 else float(correct_preds) / len(q_char_tokens)

                        correct_preds = sum(title_common_with_question.values())
                        recall_tq = 0 if correct_preds == 0 else float(correct_preds) / len(question_tokens)

                        correct_preds = sum(title_common_with_question_char.values())
                        recall_tq_char = 0 if correct_preds == 0 else float(correct_preds) / len(q_char_tokens)

                        recall_wrt_question = float(recall_eq + recall_eq_char + recall_tq + recall_tq_char) / 4
                        para_infos.append((para_tokens,recall_wrt_question,len(para_tokens),recall_wrt_question,recall_eq,recall_eq_char,recall_tq,recall_tq_char,doc['is_selected']))
                    para_infos.sort(key=lambda x: (-x[1],x[2]))
                    try:
                        all_paras.append(para_infos[0])
                    except:
                        continue
                    fake_passage_tokens = []
                    for para_info in para_infos[:1]:
                        fake_passage_tokens += para_info[0]
                    sample['passages'].append({'passage_tokens': fake_passage_tokens})
            data_set.append(sample)
    return (data_set,all_paras)
_,all_paras = load_dataset(s_dev)
train_datas = [list(i) for i in all_paras]
train_datas = np.reshape(train_datas,(len(train_datas),len(train_datas[0])))
lbs = train_datas[:,-1].astype(np.int0)

X_train, X_test, y_train, y_test = train_test_split(train_datas[:,4:5],lbs, test_size=0.33, random_state=42)
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)

def paddle_reader(dataCharacter,dataLabel):
    def reader():       
        for i in xrange(len(dataLabel)):
            yield dataCharacter[i,:], int(dataLabel[i])
    return reader

train_reader=paddle_reader(X_train,y_train)
test_reader=paddle_reader(X_test,y_test)

paddle.init(use_gpu=False, trainer_count=4)
features = paddle.layer.data(
    name='features', type=paddle.data_type.dense_vector(X_train.shape[1]))
label = paddle.layer.data(
    name='label', type=paddle.data_type.integer_value(2))

fc1 = paddle.layer.fc(input=features, size=3, act=paddle.activation.Relu())
predict = paddle.layer.fc(input=fc1, size=2,act=paddle.activation.Softmax())

cost = paddle.layer.classification_cost(input=predict, label=label)
parameters = paddle.parameters.create(cost)
optimizer = paddle.optimizer.Momentum(momentum=0)
trainer = paddle.trainer.SGD(cost=cost,
                             parameters=parameters,
                             update_equation=optimizer)
train_title = "Train cost"
test_title = "Test cost"
cost_ploter = Ploter(train_title, test_title)

step = 0
# event_handler to plot a figure
def event_handler_plot(event):
    global step
    if isinstance(event, paddle.event.EndIteration):
        if step % 10 == 0:
            print(train_title, step, event.cost)
        step += 1
    if isinstance(event, paddle.event.EndPass):
        # save parameters
        with open('params_pass_%d.tar' % event.pass_id, 'w') as f:
            trainer.save_parameter_to_tar(f)

        result = trainer.test(reader=paddle.batch(
            test_reader, batch_size=4**2))
        print(test_title, step, result.cost)

lists = []
def event_handler(event):
    if isinstance(event, paddle.event.EndIteration):
        if event.batch_id % 10 == 0:
            print "Pass %d, Batch %d, Cost %f, %s" % (
                event.pass_id, event.batch_id, event.cost, event.metrics)
    if isinstance(event, paddle.event.EndPass):
        # save parameters
        with open('params_pass_%d.tar' % event.pass_id, 'w') as f:
            trainer.save_parameter_to_tar(f)

        result = trainer.test(reader=paddle.batch(
            test_reader, batch_size=4**2))
        print("Test with Pass {}, Cost {}, {} ".format(event.pass_id, result.cost, result.metrics))
        lists.append((event.pass_id, result.cost,
                      result.metrics['classification_error_evaluator']))
trainer.train(
    reader=paddle.batch(
        paddle.reader.shuffle(
            train_reader, buf_size=4**4),
        batch_size=4**2),
    #feeding=feeding,
    event_handler=event_handler_plot,
    num_passes=1)

test_data_creator = test_reader()  
test_data = []  
test_label = []  
  
for item in test_data_creator:  
    test_data.append((item[0],))  
    test_label.append(item[1])
probs = paddle.infer(
    output_layer=predict,parameters=parameters,input=test_data)

from sklearn.metrics import accuracy_score
print(accuracy_score(test_label,np.asarray(probs[:,-1]>=0.50,dtype=np.int0)))
'''

# %%
with open('bst_para.py',mode='w',encoding='utf-8') as f:
    f.write(bst_para_str)

# %%
# !python2 bst_para.py
# Out:
# ((15612, 1), (15612,), (7690, 1), (7690,))
# I0624 10:59:00.687331   724 Util.cpp:166] commandline:  --use_gpu=False --trainer_count=4
# W0624 10:59:00.687381   724 CpuId.h:112] PaddlePaddle wasn't compiled to use avx instructions, but these are available on your machine and could speed up CPU computations via CMAKE .. -DWITH_AVX=ON
# I0624 10:59:00.695169   724 GradientMachine.cpp:94] Initing parameters..
# I0624 10:59:00.695209   724 GradientMachine.cpp:101] Init parameters done.
# ('Train cost', 0, 0.6529005169868469)
# ('Train cost', 10, 0.734377920627594)
# ('Train cost', 20, 0.7815766334533691)
# ('Train cost', 30, 0.6830152273178101)
# ('Train cost', 40, 0.6783555746078491)
# ('Train cost', 50, 0.6414922475814819)
# ('Train cost', 60, 0.7307005524635315)
# ('Train cost', 70, 0.7159216403961182)
# ('Train cost', 80, 0.6731569170951843)
# ('Train cost', 90, 0.6336798071861267)
# ('Train cost', 100, 0.6371124982833862)
# ('Train cost', 110, 0.6520087718963623)
# ('Train cost', 120, 0.7425971031188965)
# ('Train cost', 130, 0.6979072690010071)
# ('Train cost', 140, 0.6810276508331299)
# ('Train cost', 150, 0.6624369025230408)
# ('Train cost', 160, 0.6253795027732849)
# ('Train cost', 170, 0.6135817170143127)
# ('Train cost', 180, 0.6238178014755249)
# ('Train cost', 190, 0.7282385230064392)
# ('Train cost', 200, 0.6217949986457825)
# ('Train cost', 210, 0.7152408957481384)
# ('Train cost', 220, 0.7616607546806335)
# ('Train cost', 230, 0.6830161809921265)
# ('Train cost', 240, 0.6768017411231995)
# ('Train cost', 250, 0.6745092868804932)
# ('Train cost', 260, 0.7046175003051758)
# ('Train cost', 270, 0.6332312822341919)
# ('Train cost', 280, 0.7020543813705444)
# ('Train cost', 290, 0.700686514377594)
# ('Train cost', 300, 0.7034855484962463)
# ('Train cost', 310, 0.6316292881965637)
# ('Train cost', 320, 0.655101478099823)
# ('Train cost', 330, 0.6549251079559326)
# ('Train cost', 340, 0.6776795983314514)
# ('Train cost', 350, 0.6210116147994995)
# ('Train cost', 360, 0.6309712529182434)
# ('Train cost', 370, 0.618087112903595)
# ('Train cost', 380, 0.633131742477417)
# ('Train cost', 390, 0.6093430519104004)
# ('Train cost', 400, 0.6683552861213684)
# ('Train cost', 410, 0.7277428507804871)
# ('Train cost', 420, 0.6021265387535095)
# ('Train cost', 430, 0.6114825010299683)
# ('Train cost', 440, 0.6920566558837891)
# ('Train cost', 450, 0.7101777195930481)
# ('Train cost', 460, 0.6775042414665222)
# ('Train cost', 470, 0.6936365962028503)
# ('Train cost', 480, 0.6652702689170837)
# ('Train cost', 490, 0.6666662693023682)
# ('Train cost', 500, 0.7158167958259583)
# ('Train cost', 510, 0.6988024115562439)
# ('Train cost', 520, 0.6946600079536438)
# ('Train cost', 530, 0.694420576095581)
# ('Train cost', 540, 0.6853524446487427)
# ('Train cost', 550, 0.6359554529190063)
# ('Train cost', 560, 0.6672546863555908)
# ('Train cost', 570, 0.7112097144126892)
# ('Train cost', 580, 0.6413751840591431)
# ('Train cost', 590, 0.717060923576355)
# ('Train cost', 600, 0.5951775908470154)
# ('Train cost', 610, 0.5589433908462524)
# ('Train cost', 620, 0.6516368985176086)
# ('Train cost', 630, 0.7276198863983154)
# ('Train cost', 640, 0.658352255821228)
# ('Train cost', 650, 0.6761576533317566)
# ('Train cost', 660, 0.6382041573524475)
# ('Train cost', 670, 0.6276388168334961)
# ('Train cost', 680, 0.715483546257019)
# ('Train cost', 690, 0.737628161907196)
# ('Train cost', 700, 0.7733116149902344)
# ('Train cost', 710, 0.6665260791778564)
# ('Train cost', 720, 0.7472416162490845)
# ('Train cost', 730, 0.7541743516921997)
# ('Train cost', 740, 0.6571979522705078)
# ('Train cost', 750, 0.6736514568328857)
# ('Train cost', 760, 0.6732257008552551)
# ('Train cost', 770, 0.5801147818565369)
# ('Train cost', 780, 0.7361775040626526)
# ('Train cost', 790, 0.7170597314834595)
# ('Train cost', 800, 0.6854280233383179)
# ('Train cost', 810, 0.7049729824066162)
# ('Train cost', 820, 0.6415574550628662)
# ('Train cost', 830, 0.6905077695846558)
# ('Train cost', 840, 0.6590902209281921)
# ('Train cost', 850, 0.6958461999893188)
# ('Train cost', 860, 0.6405296325683594)
# ('Train cost', 870, 0.6977499127388)
# ('Train cost', 880, 0.6596295833587646)
# ('Train cost', 890, 0.6400836110115051)
# ('Train cost', 900, 0.6752365231513977)
# ('Train cost', 910, 0.6814417243003845)
# ('Train cost', 920, 0.6529049277305603)
# ('Train cost', 930, 0.6527674198150635)
# ('Train cost', 940, 0.6600685119628906)
# ('Train cost', 950, 0.6559561491012573)
# ('Train cost', 960, 0.6384311318397522)
# ('Train cost', 970, 0.746870756149292)
# ('Test cost', 976, 0.6698930047733421)
# 0.6041612483745123

# %% [markdown]
# ## 3. 加载 github 中的评估代码 和 修改para 选择的 tf-baseline 代码
# baseline 代码只修改两处：
# 1. 修改 dataset.py --> _load_dataset方法 >
# before:
# ```
# recall_wrt_question = recall_eq
# ```
# after:
# ```python
# recall_wrt_question = float(recall_eq + recall_eq_char) / 2
# ```
# 2. 修改 run.py --> prepare方法 >
# before:
# ```python
# vocab.randomly_init_embeddings(args.embed_size)
# ```
# after:
# ```python
# if args.use_embe:
#     vocab.load_pretrained_embeddings(embedding_path='./100_ver_not_pure.bin')
# else:
# 	  vocab.randomly_init_embeddings(args.embed_size)
# ```

# %%
# %%bash
# utils_base_url='https://raw.githubusercontent.com/baidu/DuReader/master/utils'
# utils_files=("__init__.py" "dureader_eval.py" "get_vocab.py" "preprocess.py" "download_thirdparty.sh")
#
# download() {
#     local metric=$1; shift;
#     local base_url=$1; shift;
#     local fnames=($@);
#
#     mkdir -p ${metric}
#     for fname in ${fnames[@]};
#     do
#         printf "downloading: %s\n" ${base_url}/${fname}
#         wget --no-check-certificate ${base_url}/${fname} -O ${metric}/${fname}
#     done
# }
# # prepare utils
# download "utils" ${utils_base_url} ${utils_files[@]}
# Out:
# downloading: https://raw.githubusercontent.com/baidu/DuReader/master/utils/__init__.py
# downloading: https://raw.githubusercontent.com/baidu/DuReader/master/utils/dureader_eval.py
# downloading: https://raw.githubusercontent.com/baidu/DuReader/master/utils/get_vocab.py
# downloading: https://raw.githubusercontent.com/baidu/DuReader/master/utils/preprocess.py
# downloading: https://raw.githubusercontent.com/baidu/DuReader/master/utils/download_thirdparty.sh
# --2018-06-24 11:03:38--  https://raw.githubusercontent.com/baidu/DuReader/master/utils/__init__.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.228.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.228.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1251 (1.2K) [text/plain]
# Saving to: ‘utils/__init__.py’
#
#      0K .                                                     100% 17.0M=0s
#
# 2018-06-24 11:03:41 (17.0 MB/s) - ‘utils/__init__.py’ saved [1251/1251]
#
# --2018-06-24 11:03:41--  https://raw.githubusercontent.com/baidu/DuReader/master/utils/dureader_eval.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.228.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.228.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19017 (19K) [text/plain]
# Saving to: ‘utils/dureader_eval.py’
#
#      0K .......... ........                                   100% 84.3K=0.2s
#
# 2018-06-24 11:03:43 (84.3 KB/s) - ‘utils/dureader_eval.py’ saved [19017/19017]
#
# --2018-06-24 11:03:43--  https://raw.githubusercontent.com/baidu/DuReader/master/utils/get_vocab.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.228.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.228.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2269 (2.2K) [text/plain]
# Saving to: ‘utils/get_vocab.py’
#
#      0K ..                                                    100% 24.0M=0s
#
# 2018-06-24 11:03:45 (24.0 MB/s) - ‘utils/get_vocab.py’ saved [2269/2269]
#
# --2018-06-24 11:03:45--  https://raw.githubusercontent.com/baidu/DuReader/master/utils/preprocess.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.228.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.228.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8098 (7.9K) [text/plain]
# Saving to: ‘utils/preprocess.py’
#
#      0K .......                                               100% 67.0M=0s
#
# 2018-06-24 11:03:46 (67.0 MB/s) - ‘utils/preprocess.py’ saved [8098/8098]
#
# --2018-06-24 11:03:46--  https://raw.githubusercontent.com/baidu/DuReader/master/utils/download_thirdparty.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.228.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.228.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1814 (1.8K) [text/plain]
# Saving to: ‘utils/download_thirdparty.sh’
#
#      0K .                                                     100% 22.7M=0s
#
# 2018-06-24 11:03:57 (22.7 MB/s) - ‘utils/download_thirdparty.sh’ saved [1814/1814]

# %%
# !cd utils && bash download_thirdparty.sh
# Out:
# downloading: https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/rouge/__init__.py
# --2018-06-24 11:06:34--  https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/rouge/__init__.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.72.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.72.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23 [text/plain]
# Saving to: ‘rouge_metric/__init__.py’
#
# rouge_metric/__init 100%[=====================>]      23  --.-KB/s   in 0s
#
# 2018-06-24 11:06:39 (34.7 MB/s) - ‘rouge_metric/__init__.py’ saved [23/23]
#
# downloading: https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/rouge/rouge.py
# --2018-06-24 11:06:39--  https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/rouge/rouge.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.72.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.72.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3643 (3.6K) [text/plain]
# Saving to: ‘rouge_metric/rouge.py’
#
# rouge_metric/rouge. 100%[=====================>]   3.56K  --.-KB/s   in 0s
#
# 2018-06-24 11:06:41 (43.1 MB/s) - ‘rouge_metric/rouge.py’ saved [3643/3643]
#
# downloading: https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/bleu/LICENSE
# --2018-06-24 11:06:41--  https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/bleu/LICENSE
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.72.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.72.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1105 (1.1K) [text/plain]
# Saving to: ‘bleu_metric/LICENSE’
#
# bleu_metric/LICENSE 100%[=====================>]   1.08K  --.-KB/s   in 0s
#
# 2018-06-24 11:06:42 (20.0 MB/s) - ‘bleu_metric/LICENSE’ saved [1105/1105]
#
# downloading: https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/bleu/__init__.py
# --2018-06-24 11:06:42--  https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/bleu/__init__.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.72.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.72.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21 [text/plain]
# Saving to: ‘bleu_metric/__init__.py’
#
# bleu_metric/__init_ 100%[=====================>]      21  --.-KB/s   in 0s
#
# 2018-06-24 11:06:44 (26.4 MB/s) - ‘bleu_metric/__init__.py’ saved [21/21]
#
# downloading: https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/bleu/bleu.py
# --2018-06-24 11:06:44--  https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/bleu/bleu.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.72.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.72.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1246 (1.2K) [text/plain]
# Saving to: ‘bleu_metric/bleu.py’
#
# bleu_metric/bleu.py 100%[=====================>]   1.22K  --.-KB/s   in 0s
#
# 2018-06-24 11:06:46 (27.8 MB/s) - ‘bleu_metric/bleu.py’ saved [1246/1246]
#
# downloading: https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/bleu/bleu_scorer.py
# --2018-06-24 11:06:46--  https://raw.githubusercontent.com/tylin/coco-caption/master/pycocoevalcap/bleu/bleu_scorer.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.72.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.72.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8703 (8.5K) [text/plain]
# Saving to: ‘bleu_metric/bleu_scorer.py’
#
# bleu_metric/bleu_sc 100%[=====================>]   8.50K  --.-KB/s   in 0s
#
# 2018-06-24 11:06:49 (106 MB/s) - ‘bleu_metric/bleu_scorer.py’ saved [8703/8703]
#
# RefactoringTool: Skipping optional fixer: buffer
# RefactoringTool: Skipping optional fixer: idioms
# RefactoringTool: Skipping optional fixer: set_literal
# RefactoringTool: Skipping optional fixer: ws_comma
# RefactoringTool: Refactored ../utils/bleu_metric/bleu_scorer.py
# --- ../utils/bleu_metric/bleu_scorer.py	(original)
# +++ ../utils/bleu_metric/bleu_scorer.py	(refactored)
# @@ -26,8 +26,8 @@
#      can take string arguments as well."""
#      words = s.split()
#      counts = defaultdict(int)
# -    for k in xrange(1,n+1):
# -        for i in xrange(len(words)-k+1):
# +    for k in range(1,n+1):
# +        for i in range(len(words)-k+1):
#              ngram = tuple(words[i:i+k])
#              counts[ngram] += 1
#      return (len(words), counts)
# @@ -42,7 +42,7 @@
#      for ref in refs:
#          rl, counts = precook(ref, n)
#          reflen.append(rl)
# -        for (ngram,count) in counts.iteritems():
# +        for (ngram,count) in counts.items():
#              maxcounts[ngram] = max(maxcounts.get(ngram,0), count)
#
#      # Calculate effective reference sentence length.
# @@ -57,10 +57,10 @@
#
#      return (reflen, maxcounts)
#
# -def cook_test(test, (reflen, refmaxcounts), eff=None, n=4):
# +def cook_test(test, xxx_todo_changeme, eff=None, n=4):
#      '''Takes a test sentence and returns an object that
#      encapsulates everything that BLEU needs to know about it.'''
# -
# +    (reflen, refmaxcounts) = xxx_todo_changeme
#      testlen, counts = precook(test, n, True)
#
#      result = {}
# @@ -74,10 +74,10 @@
#
#      result["testlen"] = testlen
#
# -    result["guess"] = [max(0,testlen-k+1) for k in xrange(1,n+1)]
# +    result["guess"] = [max(0,testlen-k+1) for k in range(1,n+1)]
#
#      result['correct'] = [0]*n
# -    for (ngram, count) in counts.iteritems():
# +    for (ngram, count) in counts.items():
#          result["correct"][len(ngram)-1] += min(refmaxcounts.get(ngram,0), count)
#
#      return result
# @@ -224,40 +224,40 @@
#              self._reflen += reflen
#
#              for key in ['guess','correct']:
# -                for k in xrange(n):
# +                for k in range(n):
#                      totalcomps[key][k] += comps[key][k]
#
#              # append per image bleu score
#              bleu = 1.
# -            for k in xrange(n):
# +            for k in range(n):
#                  bleu *= (float(comps['correct'][k]) + tiny) \
#                          /(float(comps['guess'][k]) + small)
#                  bleu_list[k].append(bleu ** (1./(k+1)))
#              ratio = (testlen + tiny) / (reflen + small) ## N.B.: avoid zero division
#              if ratio < 1:
# -                for k in xrange(n):
# +                for k in range(n):
#                      bleu_list[k][-1] *= math.exp(1 - 1/ratio)
#
#              if verbose > 1:
# -                print comps, reflen
# +                print(comps, reflen)
#
#          totalcomps['reflen'] = self._reflen
#          totalcomps['testlen'] = self._testlen
#
#          bleus = []
#          bleu = 1.
# -        for k in xrange(n):
# +        for k in range(n):
#              bleu *= float(totalcomps['correct'][k] + tiny) \
#                      / (totalcomps['guess'][k] + small)
#              bleus.append(bleu ** (1./(k+1)))
#          ratio = (self._testlen + tiny) / (self._reflen + small) ## N.B.: avoid zero division
#          if ratio < 1:
# -            for k in xrange(n):
# +            for k in range(n):
#                  bleus[k] *= math.exp(1 - 1/ratio)
#
#          if verbose > 0:
# -            print totalcomps
# -            print "ratio:", ratio
# +            print(totalcomps)
# +            print("ratio:", ratio)
#
#          self._score = bleus
#          return self._score, bleu_list
# RefactoringTool: Files that were modified:
# RefactoringTool: ../utils/bleu_metric/bleu_scorer.py
# RefactoringTool: Skipping optional fixer: buffer
# RefactoringTool: Skipping optional fixer: idioms
# RefactoringTool: Skipping optional fixer: set_literal
# RefactoringTool: Skipping optional fixer: ws_comma
# RefactoringTool: Refactored ../utils/bleu_metric/bleu.py
# --- ../utils/bleu_metric/bleu.py	(original)
# +++ ../utils/bleu_metric/bleu.py	(refactored)
# @@ -8,7 +8,7 @@
#  # Last Modified : Thu 19 Mar 2015 09:13:28 PM PDT
#  # Authors : Hao Fang <hfang@uw.edu> and Tsung-Yi Lin <tl483@cornell.edu>
#
# -from bleu_scorer import BleuScorer
# +from .bleu_scorer import BleuScorer
#
#
#  class Bleu:
# @@ -20,8 +20,8 @@
#
#      def compute_score(self, gts, res):
#
# -        assert(gts.keys() == res.keys())
# -        imgIds = gts.keys()
# +        assert(list(gts.keys()) == list(res.keys()))
# +        imgIds = list(gts.keys())
#
#          bleu_scorer = BleuScorer(n=self._n)
#          for id in imgIds:
# RefactoringTool: Files that were modified:
# RefactoringTool: ../utils/bleu_metric/bleu.py

# %%
# !rm -rf rc_tf

# %%
# !git clone https://github.com/312shan/rc_tf.git
# Out:
# Cloning into 'rc_tf'...
# remote: Counting objects: 59, done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 59 (delta 23), reused 45 (delta 12), pack-reused 0
# Unpacking objects: 100% (59/59), done.
# Checking connectivity... done.

# %%
# !cp -r utils rc_tf/

# %%
# !python -V
# Out:
# Python 3.5.2 :: Continuum Analytics, Inc.

# %%
# !du -h 100_ver_not_pure.bin
# Out:
# 239M	100_ver_not_pure.bin

# %%
# !du -h ./data/models/
# Out:
# 4.0K	./data/models/

# %%
# !rm -vr ./data/
# Out:
# removed directory: ‘./data/summary’
# removed ‘./data/dev.de-en.de’
# removed ‘./data/test.de-en.en’
# removed ‘./data/dev.de-en.en’
# removed ‘./data/test.de-en.de’
# removed ‘./data/train.de-en.de’
# removed ‘./data/train.de-en.en’
# removed ‘./data/results/test.predicted.json’
# removed directory: ‘./data/results’
# removed directory: ‘./data’

# %%
# %%time
# !pip install tensorflow-gpu==1.2
# !python rc_tf/run.py --prepare --embed_size 100 --use_embe 1
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: tensorflow-gpu==1.2 in /opt/conda/lib/python3.5/site-packages (1.2.0)
# Requirement already satisfied: markdown==2.2.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (2.2.0)
# Requirement already satisfied: protobuf>=3.2.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (3.5.2.post1)
# Requirement already satisfied: html5lib==0.9999999 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (0.9999999)
# Requirement already satisfied: werkzeug>=0.11.10 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (0.14.1)
# Requirement already satisfied: bleach==1.5.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.5.0)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (0.29.0)
# Requirement already satisfied: backports.weakref==1.0rc1 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.0rc1)
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.14.2)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.11.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.5/site-packages/setuptools-27.2.0-py3.5.egg (from protobuf>=3.2.0->tensorflow-gpu==1.2) (27.2.0)
# tensorboard 1.6.0 has requirement markdown>=2.6.8, but you'll have markdown 2.2.0 which is incompatible.
# 2018-06-24 11:36:10,313 - brc - INFO - Running with args : Namespace(algo='BIDAF', batch_size=32, brc_dir='./data/baidu', dev_files=['/mnt/datasets/dureader/preprocessed/devset/search.dev.json'], dropout_keep_prob=1, embed_size=100, epochs=10, evaluate=False, gpu='0', hidden_size=150, is_restore=0, learning_rate=0.001, log_path=None, max_a_len=200, max_p_len=500, max_p_num=5, max_q_len=60, model_dir='./data/models/', optim='adam', predict=False, prepare=True, result_dir='./data/results/', summary_dir='./data/summary/', test_files=['/mnt/datasets/dureader/preprocessed/testset/search.test.json'], train=False, train_files=['/mnt/datasets/dureader/preprocessed/trainset/search.train.json'], use_embe=1, vocab_dir='./data/vocab/', weight_decay=0)
# 2018-06-24 11:36:10,313 - brc - INFO - Checking the data files...
# 2018-06-24 11:36:10,313 - brc - INFO - Preparing the directories...
# 2018-06-24 11:36:10,313 - brc - INFO - Building vocabulary...
# 2018-06-24 11:37:32,188 - brc - INFO - Train set size: 86982 questions.
# 2018-06-24 11:37:56,551 - brc - INFO - Dev set size: 5000 questions.
# 2018-06-24 11:40:10,871 - brc - INFO - Test set size: 30000 questions.
# 2018-06-24 11:41:31,835 - brc - INFO - After filter 143915 tokens, the final vocab size is 245516
# 2018-06-24 11:41:31,835 - brc - INFO - Assigning embeddings...
# 2018-06-24 11:42:06,584 - brc - INFO - Saving vocab...
# 2018-06-24 11:42:07,639 - brc - INFO - Done with preparing!
# CPU times: user 7 s, sys: 944 ms, total: 7.95 s
# Wall time: 6min 19s

# %%
# !du -h data/vocab/vocab.data
# Out:
# 188M	data/vocab/vocab.data

# %%
# !du -h ./data/models/
# Out:
# 4.0K	./data/models/

# %%
# !rm 100_ver_not_pure.bin

# %%
# %%time
# 如果要重新加载上一次的模型，或中断了训练需要重新加载之前训练得模型，增加参数 --is_restore 1 即可
# !pip install tensorflow-gpu==1.2
# !python rc_tf/run.py --train --algo BIDAF --epochs 3 --embed_size 100 --batch_size 48 --train_files $z_train $s_train
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: tensorflow-gpu==1.2 in /opt/conda/lib/python3.5/site-packages (1.2.0)
# Requirement already satisfied: html5lib==0.9999999 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (0.9999999)
# Requirement already satisfied: backports.weakref==1.0rc1 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.0rc1)
# Requirement already satisfied: protobuf>=3.2.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (3.5.2.post1)
# Requirement already satisfied: markdown==2.2.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (2.2.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.11.0)
# Requirement already satisfied: bleach==1.5.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.5.0)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (0.29.0)
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.14.2)
# Requirement already satisfied: werkzeug>=0.11.10 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (0.14.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.5/site-packages/setuptools-27.2.0-py3.5.egg (from protobuf>=3.2.0->tensorflow-gpu==1.2) (27.2.0)
# tensorboard 1.6.0 has requirement markdown>=2.6.8, but you'll have markdown 2.2.0 which is incompatible.
# 2018-06-24 23:32:50,868 - brc - INFO - Running with args : Namespace(algo='BIDAF', batch_size=48, brc_dir='./data/baidu', dev_files=['/mnt/datasets/dureader/preprocessed/devset/search.dev.json'], dropout_keep_prob=1, embed_size=100, epochs=2, evaluate=False, gpu='0', hidden_size=150, is_restore=1, learning_rate=0.001, log_path=None, max_a_len=200, max_p_len=500, max_p_num=5, max_q_len=60, model_dir='./data/models/', optim='adam', predict=False, prepare=False, result_dir='./data/results/', summary_dir='./data/summary/', test_files=['/mnt/datasets/dureader/preprocessed/testset/search.test.json'], train=True, train_files=['/mnt/datasets/dureader/preprocessed/trainset/zhidao.train.json', '/mnt/datasets/dureader/preprocessed/trainset/search.train.json'], use_embe=0, vocab_dir='./data/vocab/', weight_decay=0)
# 2018-06-24 23:32:50,868 - brc - INFO - Load data_set and vocab...
# 2018-06-24 23:37:02,943 - brc - INFO - Train set size: 171623 questions.
# 2018-06-24 23:37:27,169 - brc - INFO - Dev set size: 5000 questions.
# 2018-06-24 23:37:27,169 - brc - INFO - Converting text into ids...
# 2018-06-24 23:39:37,516 - brc - INFO - Initialize the model...
# 2018-06-24 23:39:42,403 - brc - INFO - Time to build graph: 4.641522645950317 s
# 2018-06-24 23:39:50,475 - brc - INFO - There are 3013803 parameters in the model
# 2018-06-24 23:39:52,484 - brc - INFO - Model restored from ./data/models/, with prefix BIDAF
# 2018-06-24 23:39:52,484 - brc - INFO - Training the model...
# 2018-06-24 23:39:52,484 - brc - INFO - Training the model for epoch 1
# 2018-06-24 23:41:55,990 - brc - INFO - Average loss from batch 1 to 50 is 6.5287110805511475
# 2018-06-24 23:44:01,597 - brc - INFO - Average loss from batch 51 to 100 is 6.6122193527221675
# 2018-06-24 23:46:06,330 - brc - INFO - Average loss from batch 101 to 150 is 6.47606348991394
# 2018-06-24 23:48:13,254 - brc - INFO - Average loss from batch 151 to 200 is 6.622999305725098
# 2018-06-24 23:50:16,342 - brc - INFO - Average loss from batch 201 to 250 is 6.5526097393035885
# 2018-06-24 23:52:20,060 - brc - INFO - Average loss from batch 251 to 300 is 6.497793064117432
# 2018-06-24 23:54:24,096 - brc - INFO - Average loss from batch 301 to 350 is 6.569502601623535
# 2018-06-24 23:56:29,917 - brc - INFO - Average loss from batch 351 to 400 is 6.5761655330657955
# 2018-06-24 23:58:36,034 - brc - INFO - Average loss from batch 401 to 450 is 6.610643692016602
# 2018-06-25 00:00:40,966 - brc - INFO - Average loss from batch 451 to 500 is 6.504024639129638
# 2018-06-25 00:02:44,653 - brc - INFO - Average loss from batch 501 to 550 is 6.468767461776733
# 2018-06-25 00:04:48,840 - brc - INFO - Average loss from batch 551 to 600 is 6.526784372329712
# 2018-06-25 00:06:54,701 - brc - INFO - Average loss from batch 601 to 650 is 6.636761856079102
# 2018-06-25 00:08:57,204 - brc - INFO - Average loss from batch 651 to 700 is 6.52414400100708
# 2018-06-25 00:11:02,903 - brc - INFO - Average loss from batch 701 to 750 is 6.618663215637207
# 2018-06-25 00:13:06,865 - brc - INFO - Average loss from batch 751 to 800 is 6.581932649612427
# 2018-06-25 00:15:13,335 - brc - INFO - Average loss from batch 801 to 850 is 6.525018339157104
# 2018-06-25 00:17:17,422 - brc - INFO - Average loss from batch 851 to 900 is 6.634860525131225
# 2018-06-25 00:19:18,837 - brc - INFO - Average loss from batch 901 to 950 is 6.50121319770813
# 2018-06-25 00:21:22,295 - brc - INFO - Average loss from batch 951 to 1000 is 6.482594585418701
# 2018-06-25 00:23:24,946 - brc - INFO - Average loss from batch 1001 to 1050 is 6.455232257843018
# 2018-06-25 00:25:31,426 - brc - INFO - Average loss from batch 1051 to 1100 is 6.515383996963501
# 2018-06-25 00:27:36,747 - brc - INFO - Average loss from batch 1101 to 1150 is 6.603311214447022
# 2018-06-25 00:29:39,243 - brc - INFO - Average loss from batch 1151 to 1200 is 6.683057737350464
# 2018-06-25 00:31:44,345 - brc - INFO - Average loss from batch 1201 to 1250 is 6.570294818878174
# 2018-06-25 00:33:49,114 - brc - INFO - Average loss from batch 1251 to 1300 is 6.568730525970459
# 2018-06-25 00:35:55,721 - brc - INFO - Average loss from batch 1301 to 1350 is 6.639172887802124
# 2018-06-25 00:37:59,380 - brc - INFO - Average loss from batch 1351 to 1400 is 6.596838827133179
# 2018-06-25 00:40:00,195 - brc - INFO - Average loss from batch 1401 to 1450 is 6.484830436706543
# 2018-06-25 00:42:03,088 - brc - INFO - Average loss from batch 1451 to 1500 is 6.58176854133606
# 2018-06-25 00:44:09,324 - brc - INFO - Average loss from batch 1501 to 1550 is 6.623828039169312
# 2018-06-25 00:46:16,576 - brc - INFO - Average loss from batch 1551 to 1600 is 6.471184606552124
# 2018-06-25 00:48:18,150 - brc - INFO - Average loss from batch 1601 to 1650 is 6.604674644470215
# 2018-06-25 00:50:20,515 - brc - INFO - Average loss from batch 1651 to 1700 is 6.632332706451416
# 2018-06-25 00:52:28,081 - brc - INFO - Average loss from batch 1701 to 1750 is 6.455319461822509
# 2018-06-25 00:54:31,932 - brc - INFO - Average loss from batch 1751 to 1800 is 6.555502948760986
# 2018-06-25 00:56:42,642 - brc - INFO - Average loss from batch 1801 to 1850 is 6.513921489715576
# 2018-06-25 00:58:47,413 - brc - INFO - Average loss from batch 1851 to 1900 is 6.497624998092651
# 2018-06-25 01:00:49,791 - brc - INFO - Average loss from batch 1901 to 1950 is 6.5711134243011475
# 2018-06-25 01:02:54,319 - brc - INFO - Average loss from batch 1951 to 2000 is 6.590330467224121
# 2018-06-25 01:05:00,792 - brc - INFO - Average loss from batch 2001 to 2050 is 6.565726251602173
# 2018-06-25 01:07:06,199 - brc - INFO - Average loss from batch 2051 to 2100 is 6.635450658798217
# 2018-06-25 01:09:11,194 - brc - INFO - Average loss from batch 2101 to 2150 is 6.46269383430481
# 2018-06-25 01:11:12,175 - brc - INFO - Average loss from batch 2151 to 2200 is 6.693778076171875
# 2018-06-25 01:13:16,743 - brc - INFO - Average loss from batch 2201 to 2250 is 6.638568382263184
# 2018-06-25 01:15:22,346 - brc - INFO - Average loss from batch 2251 to 2300 is 6.431535139083862
# 2018-06-25 01:17:29,256 - brc - INFO - Average loss from batch 2301 to 2350 is 6.583514671325684
# 2018-06-25 01:19:32,924 - brc - INFO - Average loss from batch 2351 to 2400 is 6.575736970901489
# 2018-06-25 01:21:33,843 - brc - INFO - Average loss from batch 2401 to 2450 is 6.401353263854981
# 2018-06-25 01:23:35,563 - brc - INFO - Average loss from batch 2451 to 2500 is 6.590932474136353
# 2018-06-25 01:25:40,308 - brc - INFO - Average loss from batch 2501 to 2550 is 6.522476797103882
# 2018-06-25 01:27:46,980 - brc - INFO - Average loss from batch 2551 to 2600 is 6.384453496932983
# 2018-06-25 01:29:49,797 - brc - INFO - Average loss from batch 2601 to 2650 is 6.55932318687439
# 2018-06-25 01:31:52,647 - brc - INFO - Average loss from batch 2651 to 2700 is 6.5469961261749265
# 2018-06-25 01:33:56,979 - brc - INFO - Average loss from batch 2701 to 2750 is 6.702639265060425
# 2018-06-25 01:36:03,699 - brc - INFO - Average loss from batch 2751 to 2800 is 6.510435657501221
# 2018-06-25 01:38:08,887 - brc - INFO - Average loss from batch 2801 to 2850 is 6.4677152252197265
# 2018-06-25 01:40:14,576 - brc - INFO - Average loss from batch 2851 to 2900 is 6.498674325942993
# 2018-06-25 01:42:19,154 - brc - INFO - Average loss from batch 2901 to 2950 is 6.700954360961914
# 2018-06-25 01:44:25,817 - brc - INFO - Average loss from batch 2951 to 3000 is 6.433238515853882
# 2018-06-25 01:46:34,495 - brc - INFO - Average loss from batch 3001 to 3050 is 6.492403564453125
# 2018-06-25 01:48:37,639 - brc - INFO - Average loss from batch 3051 to 3100 is 6.44538743019104
# 2018-06-25 01:50:38,418 - brc - INFO - Average loss from batch 3101 to 3150 is 6.3231046104431154
# 2018-06-25 01:52:44,377 - brc - INFO - Average loss from batch 3151 to 3200 is 6.580056800842285
# 2018-06-25 01:54:47,793 - brc - INFO - Average loss from batch 3201 to 3250 is 6.591227035522461
# 2018-06-25 01:56:54,929 - brc - INFO - Average loss from batch 3251 to 3300 is 6.520123233795166
# 2018-06-25 01:58:55,858 - brc - INFO - Average loss from batch 3301 to 3350 is 6.489685697555542
# 2018-06-25 02:00:58,314 - brc - INFO - Average loss from batch 3351 to 3400 is 6.5059715843200685
# 2018-06-25 02:03:02,482 - brc - INFO - Average loss from batch 3401 to 3450 is 6.48646240234375
# 2018-06-25 02:05:06,278 - brc - INFO - Average loss from batch 3451 to 3500 is 6.54949646949768
# 2018-06-25 02:07:13,614 - brc - INFO - Average loss from batch 3501 to 3550 is 6.5369672775268555
# 2018-06-25 02:08:17,363 - brc - INFO - Average train loss for epoch 1 is 6.544911788292218
# 2018-06-25 02:08:17,364 - brc - INFO - Evaluating the model after epoch 1
# {'testlen': 392788, 'reflen': 472126, 'correct': [207039, 139796, 110857, 95059], 'guess': [392788, 387865, 382973, 378101]}
# ratio: 0.8319558761855927
# 2018-06-25 02:13:02,001 - brc - INFO - Dev eval loss 14.53130948638916
# 2018-06-25 02:13:02,001 - brc - INFO - Dev eval result: {'Bleu-4': 0.28018853372601066, 'Bleu-1': 0.4306973381594293, 'Rouge-L': 0.34762443196329235, 'Bleu-2': 0.35614945930291897, 'Bleu-3': 0.31072719196921317}
# 2018-06-25 02:13:04,775 - brc - INFO - Model saved in ./data/models/, with prefix BIDAF.
# 2018-06-25 02:13:04,775 - brc - INFO - Training the model for epoch 2
# 2018-06-25 02:15:11,185 - brc - INFO - Average loss from batch 1 to 50 is 6.189570589065552
# 2018-06-25 02:17:16,904 - brc - INFO - Average loss from batch 51 to 100 is 6.078697633743286
# 2018-06-25 02:19:20,249 - brc - INFO - Average loss from batch 101 to 150 is 6.30040509223938
# 2018-06-25 02:21:26,939 - brc - INFO - Average loss from batch 151 to 200 is 6.214388885498047
# 2018-06-25 02:23:30,105 - brc - INFO - Average loss from batch 201 to 250 is 6.1667631816864015
# 2018-06-25 02:25:35,055 - brc - INFO - Average loss from batch 251 to 300 is 6.23170334815979
# 2018-06-25 02:27:40,071 - brc - INFO - Average loss from batch 301 to 350 is 6.293635025024414
# 2018-06-25 02:29:44,701 - brc - INFO - Average loss from batch 351 to 400 is 6.340239706039429
# 2018-06-25 02:31:49,574 - brc - INFO - Average loss from batch 401 to 450 is 6.181346292495728
# 2018-06-25 02:33:55,715 - brc - INFO - Average loss from batch 451 to 500 is 6.191144618988037
# 2018-06-25 02:36:01,540 - brc - INFO - Average loss from batch 501 to 550 is 6.316395530700683
# 2018-06-25 02:38:04,800 - brc - INFO - Average loss from batch 551 to 600 is 6.233491678237915
# 2018-06-25 02:40:07,831 - brc - INFO - Average loss from batch 601 to 650 is 6.279753494262695
# 2018-06-25 02:42:12,694 - brc - INFO - Average loss from batch 651 to 700 is 6.42670184135437
# 2018-06-25 02:44:17,527 - brc - INFO - Average loss from batch 701 to 750 is 6.252927980422974
# 2018-06-25 02:46:21,731 - brc - INFO - Average loss from batch 751 to 800 is 6.294623889923096
# 2018-06-25 02:48:26,020 - brc - INFO - Average loss from batch 801 to 850 is 6.206590137481689
# 2018-06-25 02:50:32,851 - brc - INFO - Average loss from batch 851 to 900 is 6.239144458770752
# 2018-06-25 02:52:36,582 - brc - INFO - Average loss from batch 901 to 950 is 6.331577978134155
# 2018-06-25 02:54:42,611 - brc - INFO - Average loss from batch 951 to 1000 is 6.26654504776001
# 2018-06-25 02:56:48,846 - brc - INFO - Average loss from batch 1001 to 1050 is 6.300984830856323
# 2018-06-25 02:58:51,905 - brc - INFO - Average loss from batch 1051 to 1100 is 6.328059549331665
# 2018-06-25 03:00:54,891 - brc - INFO - Average loss from batch 1101 to 1150 is 6.381406717300415
# 2018-06-25 03:03:01,689 - brc - INFO - Average loss from batch 1151 to 1200 is 6.265415735244751
# 2018-06-25 03:05:04,974 - brc - INFO - Average loss from batch 1201 to 1250 is 6.315171213150024
# 2018-06-25 03:07:14,082 - brc - INFO - Average loss from batch 1251 to 1300 is 6.38149432182312
# 2018-06-25 03:09:18,580 - brc - INFO - Average loss from batch 1301 to 1350 is 6.320778341293335
# 2018-06-25 03:11:24,395 - brc - INFO - Average loss from batch 1351 to 1400 is 6.40143723487854
# 2018-06-25 03:13:32,330 - brc - INFO - Average loss from batch 1401 to 1450 is 6.355098533630371
# 2018-06-25 03:15:38,134 - brc - INFO - Average loss from batch 1451 to 1500 is 6.134465913772583
# 2018-06-25 03:17:41,586 - brc - INFO - Average loss from batch 1501 to 1550 is 6.331489849090576
# 2018-06-25 03:19:47,450 - brc - INFO - Average loss from batch 1551 to 1600 is 6.301383953094483
# 2018-06-25 03:21:53,067 - brc - INFO - Average loss from batch 1601 to 1650 is 6.375712909698486
# 2018-06-25 03:23:58,899 - brc - INFO - Average loss from batch 1651 to 1700 is 6.371649436950683
# 2018-06-25 03:26:04,403 - brc - INFO - Average loss from batch 1701 to 1750 is 6.319228448867798
# 2018-06-25 03:28:09,412 - brc - INFO - Average loss from batch 1751 to 1800 is 6.300570640563965
# 2018-06-25 03:30:10,307 - brc - INFO - Average loss from batch 1801 to 1850 is 6.205600185394287
# 2018-06-25 03:32:15,523 - brc - INFO - Average loss from batch 1851 to 1900 is 6.310789880752563
# 2018-06-25 03:34:19,395 - brc - INFO - Average loss from batch 1901 to 1950 is 6.339012336730957
# 2018-06-25 03:36:26,521 - brc - INFO - Average loss from batch 1951 to 2000 is 6.271625480651855
# 2018-06-25 03:38:29,800 - brc - INFO - Average loss from batch 2001 to 2050 is 6.225706567764282
# 2018-06-25 03:40:33,944 - brc - INFO - Average loss from batch 2051 to 2100 is 6.171103572845459
# 2018-06-25 03:42:37,516 - brc - INFO - Average loss from batch 2101 to 2150 is 6.305874719619751
# 2018-06-25 03:44:43,965 - brc - INFO - Average loss from batch 2151 to 2200 is 6.254055843353272
# 2018-06-25 03:46:49,928 - brc - INFO - Average loss from batch 2201 to 2250 is 6.204027090072632
# 2018-06-25 03:48:52,659 - brc - INFO - Average loss from batch 2251 to 2300 is 6.322454347610473
# 2018-06-25 03:50:55,849 - brc - INFO - Average loss from batch 2301 to 2350 is 6.225298566818237
# 2018-06-25 03:52:57,755 - brc - INFO - Average loss from batch 2351 to 2400 is 6.326002941131592
# 2018-06-25 03:55:00,962 - brc - INFO - Average loss from batch 2401 to 2450 is 6.455059909820557
# 2018-06-25 03:57:08,400 - brc - INFO - Average loss from batch 2451 to 2500 is 6.1714701652526855
# 2018-06-25 03:59:13,073 - brc - INFO - Average loss from batch 2501 to 2550 is 6.282257671356201
# 2018-06-25 04:01:14,893 - brc - INFO - Average loss from batch 2551 to 2600 is 6.1771672916412355
# 2018-06-25 04:03:18,903 - brc - INFO - Average loss from batch 2601 to 2650 is 6.229355430603027
# 2018-06-25 04:05:21,890 - brc - INFO - Average loss from batch 2651 to 2700 is 6.304734525680542
# 2018-06-25 04:07:27,343 - brc - INFO - Average loss from batch 2701 to 2750 is 6.377798252105713
# 2018-06-25 04:09:32,012 - brc - INFO - Average loss from batch 2751 to 2800 is 6.373502140045166
# 2018-06-25 04:11:36,646 - brc - INFO - Average loss from batch 2801 to 2850 is 6.277439403533935
# 2018-06-25 04:13:41,773 - brc - INFO - Average loss from batch 2851 to 2900 is 6.320477104187011
# 2018-06-25 04:15:51,289 - brc - INFO - Average loss from batch 2901 to 2950 is 6.410857954025269
# 2018-06-25 04:17:56,590 - brc - INFO - Average loss from batch 2951 to 3000 is 6.38038179397583
# 2018-06-25 04:20:01,377 - brc - INFO - Average loss from batch 3001 to 3050 is 6.459016695022583
# 2018-06-25 04:22:05,225 - brc - INFO - Average loss from batch 3051 to 3100 is 6.313117351531982
# 2018-06-25 04:24:09,072 - brc - INFO - Average loss from batch 3101 to 3150 is 6.408520832061767
# 2018-06-25 04:26:14,445 - brc - INFO - Average loss from batch 3151 to 3200 is 6.425330238342285
# 2018-06-25 04:28:17,365 - brc - INFO - Average loss from batch 3201 to 3250 is 6.377038917541504
# 2018-06-25 04:30:18,359 - brc - INFO - Average loss from batch 3251 to 3300 is 6.33808162689209
# 2018-06-25 04:32:24,487 - brc - INFO - Average loss from batch 3301 to 3350 is 6.341859645843506
# 2018-06-25 04:34:31,488 - brc - INFO - Average loss from batch 3351 to 3400 is 6.366409788131714
# 2018-06-25 04:36:37,707 - brc - INFO - Average loss from batch 3401 to 3450 is 6.318664045333862
# 2018-06-25 04:38:39,990 - brc - INFO - Average loss from batch 3451 to 3500 is 6.210493097305298
# 2018-06-25 04:40:46,173 - brc - INFO - Average loss from batch 3501 to 3550 is 6.48187180519104
# 2018-06-25 04:41:50,208 - brc - INFO - Average train loss for epoch 2 is 6.29956052388097
# 2018-06-25 04:41:50,209 - brc - INFO - Evaluating the model after epoch 2
# {'testlen': 390443, 'reflen': 471322, 'correct': [208746, 143031, 114166, 98216], 'guess': [390443, 385520, 380632, 375772]}
# ratio: 0.8283996927790326
# 2018-06-25 04:46:33,385 - brc - INFO - Dev eval loss 14.995401934814453
# 2018-06-25 04:46:33,386 - brc - INFO - Dev eval result: {'Bleu-4': 0.287058613115429, 'Bleu-1': 0.434608112883772, 'Rouge-L': 0.3493431335829797, 'Bleu-2': 0.3620422033858177, 'Bleu-3': 0.31734310367319685}
# 2018-06-25 04:46:36,151 - brc - INFO - Model saved in ./data/models/, with prefix BIDAF.
# 2018-06-25 04:46:36,151 - brc - INFO - Done with model training!
# CPU times: user 5min 18s, sys: 40.5 s, total: 5min 59s
# Wall time: 5h 14min 13s

# %%
# !du -h data/models/
# Out:
# 206M	data/models/

# %%
# !ls data/models/
# Out:
# BIDAF.data-00000-of-00001  BIDAF.index	BIDAF.meta  checkpoint

# %%
# %%time
# !pip install tensorflow-gpu==1.2
# !python rc_tf/run.py --predict --algo BIDAF --batch_size 48 --embed_size 100 --test_files $s_test $z_test
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: tensorflow-gpu==1.2 in /opt/conda/lib/python3.5/site-packages (1.2.0)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (0.29.0)
# Requirement already satisfied: backports.weakref==1.0rc1 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.0rc1)
# Requirement already satisfied: protobuf>=3.2.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (3.5.2.post1)
# Requirement already satisfied: html5lib==0.9999999 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (0.9999999)
# Requirement already satisfied: bleach==1.5.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.5.0)
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.14.2)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (1.11.0)
# Requirement already satisfied: markdown==2.2.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (2.2.0)
# Requirement already satisfied: werkzeug>=0.11.10 in /opt/conda/lib/python3.5/site-packages (from tensorflow-gpu==1.2) (0.14.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.5/site-packages/setuptools-27.2.0-py3.5.egg (from protobuf>=3.2.0->tensorflow-gpu==1.2) (27.2.0)
# tensorboard 1.6.0 has requirement markdown>=2.6.8, but you'll have markdown 2.2.0 which is incompatible.
# 2018-06-25 04:47:05,533 - brc - INFO - Running with args : Namespace(algo='BIDAF', batch_size=48, brc_dir='./data/baidu', dev_files=['/mnt/datasets/dureader/preprocessed/devset/search.dev.json'], dropout_keep_prob=1, embed_size=100, epochs=10, evaluate=False, gpu='0', hidden_size=150, is_restore=0, learning_rate=0.001, log_path=None, max_a_len=200, max_p_len=500, max_p_num=5, max_q_len=60, model_dir='./data/models/', optim='adam', predict=True, prepare=False, result_dir='./data/results/', summary_dir='./data/summary/', test_files=['/mnt/datasets/dureader/preprocessed/testset/search.test.json', '/mnt/datasets/dureader/preprocessed/testset/zhidao.test.json'], train=False, train_files=['/mnt/datasets/dureader/preprocessed/trainset/search.train.json'], use_embe=0, vocab_dir='./data/vocab/', weight_decay=0)
# 2018-06-25 04:47:05,533 - brc - INFO - Load data_set and vocab...
# 2018-06-25 04:51:07,137 - brc - INFO - Test set size: 60000 questions.
# 2018-06-25 04:51:07,137 - brc - INFO - Converting text into ids...
# 2018-06-25 04:51:53,653 - brc - INFO - Restoring the model...
# 2018-06-25 04:51:58,194 - brc - INFO - Time to build graph: 4.2977540493011475 s
# 2018-06-25 04:52:03,359 - brc - INFO - There are 3013803 parameters in the model
# 2018-06-25 04:52:05,901 - brc - INFO - Model restored from ./data/models/, with prefix BIDAF
# 2018-06-25 04:52:05,902 - brc - INFO - Predicting answers for test set...

# %%
# !wget -nv -O kesci_submit https://cdn.kesci.com/submit_tool/v1/kesci_submit&&chmod +x kesci_submit
# Out:
# 2018-06-23 16:31:06 URL:https://cdn.kesci.com/submit_tool/v1/kesci_submit [7842088/7842088] -> "kesci_submit" [1]

# %%
# !./kesci_submit -token 9ad470335513aaeb -file ./data/results/test.predicted.json
